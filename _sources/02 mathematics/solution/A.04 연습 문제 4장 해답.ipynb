# %% [markdown]
# # 연습 문제 4장 해답

# %% [markdown]
# #### 연습 문제 4.1.1의 답

# %%
def heaviside_step(x):
    if isinstance(x, np.ndarray):
        return np.where(x >= 0, 1, 0)
    else:
        return 1.0 if x >= 0 else 0.0 

x = np.linspace(-1, 1, 1000)

sign = np.sign(x)
step = heaviside_step(x)

plt.figure(figsize=(7, 4))
plt.subplot(121)
plt.plot(x, sign, "r-")
plt.title("부호 함수")
plt.ylim(-1.5, 1.5)
plt.subplot(122)
plt.plot(x, step, "k-")
plt.title("헤비사이드 스텝 함수")
plt.ylim(-1.5, 1.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 연습 문제 4.1.2의 답

# %% [markdown]
# $$
# \begin{align}
# \log 12 = \log{(2^2 \times 3)}
# =
# \log{2} + \log{2} + \log{3}
# =
# 0.69 \times 2 + 1.10
# =
# 2.48
# \tag{A.4.1}
# \end{align}
# $$

# %%
np.log(12)
# Out:
# 2.4849066497880004

# %% [markdown]
# #### 연습 문제 4.1.3의 답

# %% [markdown]
# $$
# \begin{align}
# y = \sigma(x) = \dfrac{1}{1 + \exp(-x)}
# \tag{A.4.2}
# \end{align}
# $$
#
# $$
# \begin{align}
# 1 + \exp(-x) = \dfrac{1}{y}
# \tag{A.4.3}
# \end{align}
# $$
#
# $$
# \begin{align}
# \exp(-x) = \dfrac{1}{y} - 1 =  \dfrac{1-y}{y}
# \tag{A.4.4}
# \end{align}
# $$
#
# $$
# \begin{align}
# \log\exp(-x) = -x = \log\dfrac{1-y}{y}
# \tag{A.4.5}
# \end{align}
# $$
#
# $$
# \begin{align}
# x = -\log\dfrac{1-y}{y} = \log\dfrac{y}{1-y}
# \tag{A.4.6}
# \end{align}
# $$
#
# $$
# \begin{align}
# \sigma^{-1}(x) =\log\dfrac{x}{1 -x}
# \tag{A.4.7}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.2.1의 답

# %% [markdown]
# | $x$  | $-0.5$ |  $0$  |  $0.5$ |  $1$  |  $1.5$ |  $2$  |  $2.5$ |
# | ---- |---- | --- | ---- | --- | ---- | --- | ---- |
# | 기울기 | $2.5$  |   $1$ | $-1$ |  $-2$  | $-1$ | $1$ | $2.5$ |

# %% [markdown]
# #### 연습 문제 4.2.2의 답

# %%
x = np.array([-.5, 0, 0.5, 1, 1.5, 2, 2.5])
y = np.array([2.5, 1, -1, -2, -1, 1, 2.5])

plt.title("도함수의 그래프")
plt.plot(x, y, 'b-')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# #### 연습 문제 4.2.3의 답

# %% [markdown]
# (1)
#
# $$
# \begin{align}
# f(x) = x^3 - 1
# \tag{A.4.8}
# \end{align}
# $$
#
# $$
# \begin{align}
# f'(x) = 3x^2
# \tag{A.4.9}
# \end{align}
# $$
#
#
# (2)
#
# $$
# \begin{align}
# f(x) = \log (x^{2}-3k)
# \tag{A.4.10}
# \end{align}
# $$
#
# $$
# \begin{align}
# g(x)=x^2-3k
# \tag{A.4.11}
# \end{align}
# $$
#
# $$
# \begin{align}
# f(g)=\log g
# \tag{A.4.12}
# \end{align}
# $$
#
# 라고 하면
#
# $$
# \begin{align}
# f'(x) =  \dfrac{df}{dg} \cdot \dfrac{dg}{dx} = \dfrac{1}{g} \cdot 2x = \dfrac{2x}{x^2-3k}
# \tag{A.4.13}
# \end{align}
# $$
#
#
# (3)
#
# $$
# \begin{align}
# f(x) =\exp({ax^b})
# \tag{A.4.14}
# \end{align}
# $$
#
# $$
# \begin{align}
# g(x)=ax^b
# \tag{A.4.15}
# \end{align}
# $$
#
# $$
# \begin{align}
# f(g)=\exp g
# \tag{A.4.16}
# \end{align}
# $$
#
# 라고 하면
#
# $$
# \begin{align}
# f'(x) =  \dfrac{df}{dg} \cdot \dfrac{dg}{dx} = \exp{g} \cdot abx^{b-1} =  abx^{b-1} \exp({ax^b})
# \tag{A.4.17}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.2.4의 답

# %% [markdown]
# $$
# \begin{align}
# f_x=2x\exp{(x^2 + 2y^2)}
# \tag{A.4.18}
# \end{align}
# $$
#
# $$
# \begin{align}
# f_y=4y\exp{(x^2 + 2y^2)}
# \tag{A.4.19}
# \end{align}
# $$
#
# $$
# \begin{align}
# f_{xx}=(4x^2 + 2)\exp{(x^2 + 2y^2)}
# \tag{A.4.20}
# \end{align}
# $$
#
# $$
# \begin{align}
# f_{xy}= 8xy\exp{(x^2 + 2y^2)}
# \tag{A.4.21}
# \end{align}
# $$
#
# $$
# \begin{align}
# f_{yx}= 8xy\exp{(x^2 + 2y^2)}
# \tag{A.4.22}
# \end{align}
# $$
#
# $$
# \begin{align}
# f_{yy}= (16y^2+4)\exp{(x^2 + 2y^2)}
# \tag{A.4.23}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.2.5의 답

# %%
import sympy

# %%
# (1)

x = sympy.symbols('x')
f = x**3 - 1
sympy.diff(f)
# Out:
# 3*x**2

# %%
# (2)

x, k = sympy.symbols('x k')
f = sympy.log(x**2 - 3*k)
sympy.diff(f, x)
# Out:
# 2*x/(-3*k + x**2)

# %%
# (3)

x, a, b = sympy.symbols('x a b')
f = sympy.exp(a*x**b)
sympy.simplify(sympy.diff(f, x))
# Out:
# a*b*x**(b - 1)*exp(a*x**b)

# %% [markdown]
# #### 연습 문제 4.2.6

# %%
x, y = sympy.symbols('x y')
f = sympy.exp(x**2 + 2*y**2)

# %%
# f_x
sympy.diff(f, x)
# Out:
# 2*x*exp(x**2 + 2*y**2)

# %%
# f_y
sympy.diff(f, y)
# Out:
# 4*y*exp(x**2 + 2*y**2)

# %%
# f_xx
sympy.diff(f, x, x)
# Out:
# 2*(2*x**2 + 1)*exp(x**2 + 2*y**2)

# %%
# f_xy
sympy.diff(f, x, y)
# Out:
# 8*x*y*exp(x**2 + 2*y**2)

# %%
# f_yx
sympy.diff(f, y, x)
# Out:
# 8*x*y*exp(x**2 + 2*y**2)

# %%
# f_yy
sympy.diff(f, y, y)
# Out:
# 4*(4*y**2 + 1)*exp(x**2 + 2*y**2)

# %% [markdown]
# #### 연습 문제 4.3.1의 답

# %% [markdown]
# (1)
#
# $$
# \begin{align}
# x^3 + C
# \tag{A.4.24}
# \end{align}
# $$
#
# (2)
#
# $$
# \begin{align}
# x^3 - 3x^2+ x + C
# \tag{A.4.25}
# \end{align}
# $$
#
# (3)
#
# $$
# \begin{align}
# 3x^2 + 2x +4\exp(x) + 5\log(x) + C
# \tag{A.4.26}
# \end{align}
# $$
#
# (4)
#
# $$
# \begin{align}
# \log(x^2 - 1) + C
# \tag{A.4.27}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.3.2의 답

# %% [markdown]
# (1)
#
# $$
# \begin{align}
# x + \dfrac{x^2y}{2} + C(y)
# \tag{A.4.28}
# \end{align}
# $$
#
# (2)
#
# $$
# \begin{align}
# \exp(x^2 + y^2)\dfrac{y}{2} + C(y)
# \tag{A.4.29}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.3.3의 답
#
# $$
# \begin{align}
# \dfrac{\exp(x^2 + y^2)}{4}
# \tag{A.4.30}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.3.4의 답

# %%
import sympy

x, y = sympy.symbols('x y')

# %%
# 3.3.1 - (1)
f = 3 * x**2
sympy.integrate(f)
# Out:
# x**3

# %%
# 3.3.1 - 2)
f = 3 * x**2 - 6 * x + 1
sympy.integrate(f)
# Out:
# x**3 - 3*x**2 + x

# %%
# 3.3.1 - (3)
f = 2 + 6 * x + 4 * sympy.exp(x) + 5 / x
sympy.integrate(f)
# Out:
# 3*x**2 + 2*x + 4*exp(x) + 5*log(x)

# %%
# 3.3.1 - (4)
f = 2 * x / (x**2 - 1)
sympy.integrate(f)
# Out:
# log(x**2 - 1)

# %%
# 3.3.2 - (1)
f = 1 + x * y
sympy.integrate(f, x)
# Out:
# x**2*y/2 + x

# %%
# 3.3.2 - (3)
f = x * y * sympy.exp(x**2 + y**2)
sympy.integrate(f, x)
# Out:
# y*exp(x**2 + y**2)/2

# %% [markdown]
# #### 연습 문제 4.3.5의 답

# %% [markdown]
# (1)
#
# * 부정적분
#
# $$
# \begin{align}
# F(x) = x^3 - 3x^2 + x
# \tag{A.4.31}
# \end{align}
# $$
#
# $$
# \begin{align}
# F(1) - F(0) = -1
# \tag{A.4.32}
# \end{align}
# $$

# %%
x = sympy.symbols('x')
f = 3*x**2 - 6*x + 1
sympy.integrate(f, x)
# Out:
# x**3 - 3*x**2 + x

# %% [markdown]
# - 수치적분

# %%
def f(x):
    return 3 * x**2 - 6 * x + 1


sp.integrate.quad(f, 0, 1)
# Out:
# (-1.0, 1.3085085171449517e-14)

# %% [markdown]
# (2)
#
# * 부정적분
#
# $$
# \begin{align}
# F(x) = 3x^2 + 2x +4\exp(x) + 5\log(x)
# \tag{A.4.33}
# \end{align}
# $$
#
# $$
# \begin{align}
# F(10) - F(1) = 88421.502977378
# \tag{A.4.34}
# \end{align}
# $$

# %%
x = sympy.symbols('x')
f = 2 + 6 * x + 4 * sympy.exp(x) + 5 / x 
sympy.integrate(f, x)
# Out:
# 3*x**2 + 2*x + 4*exp(x) + 5*log(x)

# %% [markdown]
# * 수치 적분

# %%
def f(x):
    return 2 + 6 * x + 4 * sympy.exp(x) + 5 / x


sp.integrate.quad(f, 1, 10)
# Out:
# (88421.50297737827, 1.5276890734473408e-06)

# %% [markdown]
# #### 연습 문제 4.3.6의 답

# %%
def f(x, y):
    return 1 + (x * y)


sp.integrate.dblquad(f, -1, 1, lambda x: -1, lambda x: 1)
# Out:
# (4.0, 4.440892098500626e-14)

# %% [markdown]
# #### 연습 문제 4.4.1의 답

# %% [markdown]
# (1)
#
# $$
# \begin{align}
# \nabla f =
# \begin{bmatrix}
# \frac{\partial f}{\partial x}\\
# \frac{\partial f}{\partial y}\\
# \frac{\partial f}{\partial z}\\
# \end{bmatrix} =
# \begin{bmatrix}
# 1\\
# 1\\
# 1\\
# \end{bmatrix}
# \tag{A.4.35}
# \end{align}
# $$

# %% [markdown]
# (2)
#
# $$
# \begin{align}
# \nabla f =
# \begin{bmatrix}
# \frac{\partial f}{\partial x}\\
# \frac{\partial f}{\partial y}\\
# \frac{\partial f}{\partial z}\\
# \end{bmatrix} =
# \begin{bmatrix}
# yz\\
# xz\\
# xy\\
# \end{bmatrix}
# \tag{A.4.36}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.4.2의 답

# %%
import numpy as np
import matplotlib.pylab as plt

black = {"facecolor": "black"}

def g(x, y):
    return (4*x + 6*y - 26, 6*x + 14*y -54)

g1 = g(7, 1)
g2 = g(2, 1)

plt.plot(0, 0, 'kP', ms=10)
plt.plot(g1[0], g1[1], 'ro', ms=10)
plt.annotate('', xy=g1, xytext=(0, 0), arrowprops=black)
plt.plot(g2[0], g2[1], 'ro', ms=10)
plt.annotate('', xy=g2, xytext=(0, 0), arrowprops=black)

plt.axis("equal")
plt.show()

# %% [markdown]
# #### 연습 문제 4.4.3의 답

# %%
black = {"facecolor": "black"}

def f(x, y):
    v = 2 * x**2 + 6 * x * y + 7 * y**2 \
        - 26 * x - 54 * y + 107
    return  v

xx = np.linspace(1, 16, 100)
yy = np.linspace(-3, 6, 90)
X, Y = np.meshgrid(xx, yy)
Z = f(X, Y)

def gx(x, y):
    return 4 * x + 6 * y - 26

def gy(x, y):
    return 6 * x + 14 * y - 54

xx2 = np.linspace(1, 16, 15)
yy2 = np.linspace(-3, 6, 9)
X2, Y2 = np.meshgrid(xx2, yy2)
GX = gx(X2, Y2)
GY = gy(X2, Y2)
plt.figure(figsize=(10, 5))
plt.contour(X, Y, Z, levels=np.logspace(0, 3, 10))

x0 = (14, 4)
plt.plot(x0[0], x0[1], 'ko', ms=10)

for i in range(20):
    g = np.array((gx(x0[0], x0[1]), gy(x0[0], x0[1])))
    x_next = x0 - 0.02 * g
    plt.annotate('', xy=x_next, xytext=x0, 
                 arrowprops=black)
    x0 = x_next

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# #### 연습 문제 4.4.4의 답

# %% [markdown]
# $$
# \begin{align}
# J =
# \begin{bmatrix}
# \frac{\partial f_1}{\partial x_1} & \frac{\partial f_1}{\partial x_2} & \frac{\partial f_1}{\partial x_3} \\
# \frac{\partial f_2}{\partial x_1} & \frac{\partial f_2}{\partial x_2} & \frac{\partial f_2}{\partial x_3}
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & 1 & 1 \\
# x_2x_3 & x_1x_3 & x_1x_1
# \end{bmatrix}
# \tag{A.4.37}
# \end{align}
# $$

# %% [markdown]
# #### 연습 문제 4.4.5의 답

# %% [markdown]
# $$
# \begin{align}
# \nabla f(x)
# =
# \begin{bmatrix}
# 2x_1 \\ 2x_2 \\ 2x_3
# \end{bmatrix}
# \tag{A.4.38}
# \end{align}
# $$
#
# $$
# \begin{align}
# J\nabla f(x)
# =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & 2 & 0 \\
# 0 & 0 & 2
# \end{bmatrix}
# \tag{A.4.39}
# \end{align}
# $$
#
# $$
# \begin{align}
# H = J^T
# =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & 2 & 0 \\
# 0 & 0 & 2
# \end{bmatrix}
# \tag{A.4.40}
# \end{align}
# $$
