# %%
# %load_ext tikzmagic

# %%
# %%tikz -S fig.09.04.01.png -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,datavisualization,datavisualization.formats.functions -g fillbetween -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,-1);
# \coordinate (righttop) at (20,10);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\normalsize},
#     rv/.style={draw, minimum width=5cm, minimum height=4cm},
#     data/.style={draw, minimum size=2cm, shape aspect=2, cloud}
# }
#
# \begin{scope}[shift={(2,0)}]
# \node[rv, label={귀무가설에 따른 확률변수 분포}] (X) at (3,7) {};
# \node[data, label=below:표본 데이터 집합] (x) at (3,2) {$\{x_1,\ldots,x_N\}$};
# \draw[->] (X) -- (x);
# \node[draw, minimum width=3cm, minimum height=1cm, label=통계량 계산식] (f) at (7.5,2) {$t=f(x_1,\ldots,x_N)$};
# \draw[->] (x) -- (f);
# \node[data, label=below:통계량] (t) at (12,2) {$t$};
# \draw[->] (f) -- (t);
# \node[rv, label=귀무가설에 따른 통계량의 분포] (T) at (12,7) {};
# \draw[->] (t) -- (T);
# \node[draw, minimum width=2.5cm, minimum height=1cm, label=확률변수 변환] (f2) at (7.5,7) {$p_X(x)\! \rightarrow\! p_T(t)$};
# \draw[->] (X) -- (f2);
# \draw[->] (f2) -- (T);
# \end{scope}
#
# \begin{scope}[shift={(2.5,6)}]
# \begin{axis}[hide axis, xmin=-2, xmax=2, ymin=0, ymax=1.02, width=5cm, height=2.5cm, scale only axis=true]
# \addplot[line width=2pt, color=gray, domain=-2:2, samples=100] {
#     exp(-x*x)
# };
# \end{axis}
# \end{scope}
# \node at (4,8.5) {$p_X(x)$};
# \fill (4.1,6) circle (2pt) (4.6,6) circle (2pt) (4.9,6) circle (2pt) (5.4,6) circle (2pt) (5.6,6) circle (2pt) (6.1,6) circle (2pt);
# \node at (4.1,5.6) {$x_1$};
# \node at (6.25,5.6) {$x_N$};
#
# \begin{scope}[shift={(11.5,4.5)}]
# \begin{axis}[hide axis, xmin=-2, xmax=2, ymin=0, ymax=1.02, width=5cm, height=3.5cm, scale only axis=true]
# \addplot[line width=2pt, color=gray, domain=-2:2, samples=100] {
#     exp(-0.2*x*x)
# };
# \end{axis}
# \end{scope}
# \node at (14,8.5) {$p_T(t)$};
# \fill (14.4,6) circle (2pt);
# \node at (14.45,5.6) {$t$};
