# %% [markdown]
# $$
# \begin{align}
# \lambda\text{는}\;\text{복소수}
# \tag{fig.334.1}
# \end{align}
# $$
#
# $$
# \begin{align}
# \lambda\text{는 } N\text{개}
# \tag{fig.334.2}
# \end{align}
# $$
#
# $$
# \begin{align}
# AV=V\Lambda
# \tag{fig.334.3}
# \end{align}
# $$
#
# $$
# \begin{align}
# \sum_{i=1}^N\lambda_i = {\rm tr}A
# \tag{fig.334.4}
# \end{align}
# $$
#
# $$
# \begin{align}
# \prod_{i=1}^N\lambda_i = \det A
# \tag{fig.334.5}
# \end{align}
# $$
#
# $$
# \begin{align}
# \lambda{는}\;\text{실수}
# \tag{fig.334.6}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# V^T=V^{-1}
# \tag{fig.334.7}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# A=V^{}\Lambda^{}V^{T}
# \tag{fig.334.8}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# A=\sum_{i=1}^N \lambda_i v_i v_i^T
# \tag{fig.334.9}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# \text{음수인 고유값 }\lambda_i < 0 \text{ 포함 }
# \tag{fig.334.10}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# X\text{가 풀랭크}
# \tag{fig.334.11}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# \text{역행렬이 존재}
# \tag{fig.334.12}
# \end{align}
# $$
#
#
# $$
# \begin{align}
# \text{모든 고유값이 양수 } \lambda_i > 0
# \tag{fig.334.13}
# \end{align}
# $$
