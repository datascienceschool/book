# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (-1,-1);
# \coordinate (righttop) at (9,3);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\scriptsize}
# }
#
# \begin{scope}[shift={(-0.5,0)}, scale=0.4]
# \draw[rounded corners]
# (0,0,0) -- (5,0,0) -- (5,2,0) -- (0,2,0) -- cycle
# (0,0,0) -- (0,2,0) -- (0,2,-5) -- (5,2,-5) -- (5,0,-5) -- (5,0,0) -- cycle;
# \draw[shift={(0,0,0.2)}] (5,2,0) -- (5,2,-5);
# \coordinate (knob) at (2.5,1);
# \draw (knob) circle[radius=0.5];
# \draw[fill=white] ($(knob)+(0,0,0.3)$) circle[radius=0.5] node {$x$};
# \foreach \x in {-45, -30, ..., 135} \draw ($(knob)+(0,0,0.3)$) ++(\x:0.5) -- +(0,0,-0.3);
# \node at (4,4.5) {고장난 스피커 앰프};
# \node (label) at (5,-2) {조절나사};
# \draw[<->] (knob) ++(20:0.7) arc[radius=0.7, start angle=20, end angle=80];
# \draw[arrows={-Stealth[length=2mm]}] (label.north west) to (2.7,0.4);
# \foreach \x in {1,1.5, ..., 3} \draw ($(7,3.5)+(\x,0)$) arc[radius=\x, start angle=-10, delta angle=80];
# \node at (1.1,0.9) {각도};
# \node at (9,3) {음량 $y$};
# \end{scope}
#
# \begin{scope}[shift={(5,0)}]
# \draw[->] (-0.5,0) -- (4,0);
# \draw[->] (0,-0.5) -- (0,2);
# \node at (3,-0.2) {각도 $x$};
# \node at (0,2.3) {음량 $y$};
# \draw plot[smooth,tension=0.7] coordinates
# {(0,1) (0.5,0.3) (1,1.5) (1.5,1.1) (2,1.3) (2.5,0.6) (3,0.8)};
# \end{scope}
