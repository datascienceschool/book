# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,decorations.pathmorphing,datavisualization,datavisualization.formats.functions -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,13);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \node[draw, rectangle, rounded corners, line width=3pt, minimum width=6cm, minimum height=5cm] (X) at (10, 9) {};
# \node[draw, ellipse, line width=2pt, minimum width=5cm, minimum height=4cm] (prob) at (10, 8.8) {};
# \node[fill=white, above, font={\ttfamily\large}] at (X.north) {\Large 확률변수 $X$};
# \node[fill=white] at (prob.north) {표본공간 $\Omega$};
# \begin{scope}[shift={(10,8.25)}]
# \datavisualization[school book axes, visualize as smooth line, all axes = {ticks = {major = {at = {}}}}]
# data [format=function] {
#     var x : interval[-2:2];
#     func y = 1.8 * exp(-2 * \value x * \value x);
# };
# \end{scope}
# \node[fill=white, above=0.5cm] at (prob.south) {확률분포함수};
#
# \node[draw, cloud, line width=2pt, minimum width=5cm, minimum height=4cm] (dataset1) at (5, 2.5) {};
# \node[fill=white, above=-0.05cm of dataset1.south] {\Large 데이터 표본 집합};
# \begin{scope}[shift = {(3.3, 2)}]
# \begin{axis}[width=5cm, height=3cm, xtick=0, ytick=0, hide x axis, hide y axis]
# \addplot+[color=black, fill=gray!10, ybar interval, mark=no]
#     plot coordinates {(0, 2) (5, 15) (10, 20) (15, 10) (20, 7) (25, 0)};
# \end{axis}
# \end{scope}
# \node[fill=white, above=1cm] at (dataset1.south) {히스토그램};
# \draw[line width=1pt, ->] (X) to[bend right] node[pos=0.9, left] {실현} (dataset1) ;
#
# \node[draw, cloud, line width=2pt, minimum width=5cm, minimum height=4cm] (dataset2) at (15, 2.5) {};
# \node[fill=white, above=-0.05cm of dataset2.south] {\Large 데이터 표본 집합};
# \begin{scope}[shift = {(13.3, 2)}]
# \begin{axis}[width=5cm, height=3cm, xtick=0, ytick=0, hide x axis, hide y axis]
# \addplot+[color=black, fill=gray!10, ybar interval, mark=no]
#     plot coordinates {(0, 5) (5, 11) (10, 18) (15, 11) (20, 2) (25, 3)};
# \end{axis}
# \end{scope}
# \node[fill=white, above=0.8cm] at (dataset2.south) {히스토그램};
# \draw[line width=1pt, ->] (X) to[bend left] node[pos=0.9, right] {실현} (dataset2);
#
#
# \draw[line width=2pt, dashed] (1,6) -- (19,6);
# \node[font={\ttfamily\Large}] at (2.95, 6.5) {가상의 수학 세계};
# \node[font={\ttfamily\Large}] at (2.1, 5.5) {현실 세계};
