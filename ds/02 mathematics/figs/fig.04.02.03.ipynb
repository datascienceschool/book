# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,datavisualization,datavisualization.formats.functions -g fillbetween -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (-1,0);
# \coordinate (righttop) at (9,4);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\small}
# }
#
# \begin{scope}[shift={(0.5,1)}, scale=0.4]
# \node at (3.5, 5) {\small $x_1$의 기울기 조사};
# \draw[rounded corners]
# (0,0,0) -- (5,0,0) -- (5,2,0) -- (0,2,0) -- cycle
# (0,0,0) -- (0,2,0) -- (0,2,-5) -- (5,2,-5) -- (5,0,-5) -- (5,0,0) -- cycle;
# \draw[shift={(0,0,0.3)}] (5,2,0) -- (5,2,-5);
#
# \coordinate (knob1) at (1.2,1);
# \draw (knob1) circle[radius=0.5];
# \draw[fill=white] ($(knob1)+(0,0,0.3)$) circle[radius=0.5] node {\scriptsize $x_1$};
# \foreach \x in {-45, -30, ..., 135} \draw ($(knob1)+(0,0,0.3)$) ++(\x:0.5) -- +(0,0,-0.3);
# \node (label1) at ($(knob1)+(0,-3)$) {};
# \draw[<->] (knob1) ++(20:0.7) arc[radius=0.7, start angle=10, end angle=80];
#
# \coordinate (knob2) at (3.5,1);
# \draw (knob2) circle[radius=0.5];
# \draw[fill=white] ($(knob2)+(0,0,0.3)$) circle[radius=0.5] node {\scriptsize $x_2$};
# \foreach \x in {-45, -30, ..., 135} \draw ($(knob2)+(0,0,0.3)$) ++(\x:0.5) -- +(0,0,-0.3);
# \node (label2) at ($(knob2)+(0,-3)$) {고정};
# \draw[arrows={-Stealth[length=2mm]}] (label2.north) to ($(knob2.south)-(0,0.5)$);
# \end{scope}
#
# \begin{scope}[shift={(4.5,1)}, scale=0.4]
# \node at (3.5, 5) {\small $x_2$의 기울기 조사};
# \draw[rounded corners]
# (0,0,0) -- (5,0,0) -- (5,2,0) -- (0,2,0) -- cycle
# (0,0,0) -- (0,2,0) -- (0,2,-5) -- (5,2,-5) -- (5,0,-5) -- (5,0,0) -- cycle;
# \draw[shift={(0,0,0.3)}] (5,2,0) -- (5,2,-5);
#
# \coordinate (knob1) at (1.5,1);
# \draw (knob1) circle[radius=0.5];
# \draw[fill=white] ($(knob1)+(0,0,0.3)$) circle[radius=0.5] node {\scriptsize $x_1$};
# \foreach \x in {-45, -30, ..., 135} \draw ($(knob1)+(0,0,0.3)$) ++(\x:0.5) -- +(0,0,-0.3);
# \node (label1) at ($(knob1)+(0,-3)$) {고정};
# \draw[arrows={-Stealth[length=2mm]}] (label1.north) to ($(knob1.south)-(0,0.5)$);
#
# \coordinate (knob2) at (3.5,1);
# \draw (knob2) circle[radius=0.5];
# \draw[fill=white] ($(knob2)+(0,0,0.3)$) circle[radius=0.5] node {\scriptsize $x_2$};
# \foreach \x in {-45, -30, ..., 135} \draw ($(knob2)+(0,0,0.3)$) ++(\x:0.5) -- +(0,0,-0.3);
# \node (label2) at ($(knob2)+(0,-3)$) {};
# \draw[<->] (knob2) ++(20:0.7) arc[radius=0.7, start angle=10, end angle=80];
# \end{scope}
