# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots,pgffor -e utf-8 -l arrows.meta,calc,positioning,shapes -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,6);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
# \draw (1.25,1.5) -- (6.75,1.5) ;
# \draw (7.25,1.5) -- (12.75,1.5) ;
# \draw (13.25,1.5) -- (18.75,1.5) ;
#
# \begin{scope}[shift={(1,1.5)}]
# \begin{axis}[hide axis, width=210pt, height=200pt, line width=1pt, ymax=0.5]
# \addplot[domain=-5:4,samples=100]{exp(x - exp(x))};
# \addplot[domain=-4:4,samples=100, dashed]{0.92 * exp(-(x-0)^2 / ((1.2)^2)) / (sqrt(2*pi))};
# \end{axis}
# \end{scope}
#
# \begin{scope}[shift={(7,1.5)}]
# \begin{axis}[hide axis, width=210pt, height=200pt, line width=1pt, ymax=0.5]
# \addplot[domain=-4:4,samples=100]{0.9 * exp(-(x-0)^2 / ((0.9)^2)) / (sqrt(2*pi))};
# \end{axis}
# \end{scope}
#
# \begin{scope}[shift={(13,1.5)}]
# \begin{axis}[hide axis, width=210pt, height=200pt, line width=1pt, ymax=0.5]
# \addplot[domain=-4:5,samples=100]{exp(-(x + exp(-x)))};
# \addplot[domain=-4:4,samples=100, dashed]{0.92 * exp(-(x-0)^2 / ((1.2)^2)) / (sqrt(2*pi))};
# \end{axis}
# \end{scope}
#
# \node[anchor=base] at (4, 1) {비대칭도 $< 0$};
# \node[anchor=base] at (10, 1) {비대칭도 $= 0$};
# \node[anchor=base] at (16, 1) {비대칭도 $> 0$};
