# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots,pgffor -l arrows.meta,calc,positioning,shapes -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,6);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \begin{scope}[shift={(5,0.5)}]
# \begin{axis}[hide axis, width=400pt, height=200pt, line width=2pt, xmin=-1.8, ymax=0.26]
# \addplot[domain=-2:4,samples=100,dashed]{exp(-(x-0)^2 / (2^2)) / (2 * sqrt(2*pi))};
# \foreach \x in {-1.5, -1.1, -0.7, -0.5, -0.35, -0.21, -0.11, 0, 0.14, 0.19, 0.3, 0.5, 0.8, 1.0, 1.5, 1.9, 2.4} {
#   \edef\temp{\noexpand\fill (axis cs:\x, 0) circle (3pt);}\temp
# }
# \node at (axis cs:0,0.23) {$\bar{x}$(표본평균)};
# \draw[line width=1pt, dashed](axis cs:0,-0.1) -- (axis cs:0,0.21);
# \node at (axis cs:1.1,0.08) {$x_i$($i$번째 표본)};
# \draw[line width=1pt, dashed](axis cs:1,-0.1) -- (axis cs:1,0.06);
# \draw[line width=1pt, <->](axis cs:0,0.02) -- (axis cs:1,0.02);
# \node at (axis cs:0.5,0.035) {$x_i-\bar{x}$};
# \node at (axis cs:-.9,0.06) {$i$번째 표본과};
# \node at (axis cs:-.9,0.03) {표본평균 사이의 거리};
# \end{axis}
# \end{scope}
