# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,decorations.pathmorphing,datavisualization,datavisualization.formats.functions -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,14);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \node[draw, rectangle, rounded corners, line width=2pt, minimum width=6cm, minimum height=5cm] (X) at (10,10) {};
# \node[draw, ellipse, line width=2pt, minimum width=5cm, minimum height=4cm] (prob) at (X) {};
# \node[fill=white, above, font={\ttfamily\Large}] at (X.north) {확률변수 $X$};
# \node[fill=white] at (prob.north) {표본공간 $\Omega$};
#
# \node[draw, cloud, line width=2pt, minimum width=6cm, minimum height=5cm] (D) at (10,3) {};
# \node[fill=white, above=-0.01cm, font={\ttfamily\Large}] at (D.south) {데이터 집합 $\{x_1. x_2, \ldots\}$};
#
# \node[draw, circle, minimum width=0.5cm] (w1) at (9,11) {$\omega_1$};
# \node[right of=w1] {표본 1};
# \node[draw, circle, minimum width=0.5cm] (d1) at (8,3.5) {$x_1$};
# \node[right=3pt of d1] {데이터 1};
# \draw[->] (w1) to[bend right] (d1);
#
# \node[draw, circle, minimum width=0.5cm] (w2) at (11,9) {$\omega_2$};
# \node[left of=w2] {표본 2};
# \node[draw, circle, minimum width=0.5cm] (d2) at (10,2) {$x_2$};
# \node[right=3pt of d2] {데이터 2};
# \draw[->] (w2) to[bend left] (d2);
#
# \node at (9,6.8) {표본을 실수로 실현};
#
# \draw[line width=2pt, dashed] (1,6) -- (19,6);
# \node[font={\ttfamily\Large}] at (2.95, 6.5) {가상의 수학 세계};
# \node[font={\ttfamily\Large}] at (2.1, 5.5) {현실 세계};
