# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,6);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \tikzset{
# functionbox/.pic={
# }}
#
# \draw[rounded corners, line width=2pt] (3,1) rectangle (15,5);
# \draw[line width=1pt] (5,1) coordinate (p11) -- (6,5) coordinate (p12);
# \draw[line width=1pt] (8,1) coordinate (p21) -- (7,5) coordinate (p22);
# \draw[line width=1pt] (9,1) coordinate (p31) -- (9.5,5) coordinate (p32);
# \draw[line width=1pt] (12,1) coordinate (p41) -- (11,5) coordinate (p42);
# \draw[line width=1pt] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \node[fill=white] at (4,5) {$\Omega$};
# \node at (4.6,4.5) {$C_1$};
# \node at (6.5,4.5) {$C_2$};
# \node at (8.5,4.5) {$C_3$};
# \node at (10.5,4.5) {$C_4$};
# \node at (13,4.5) {$C_5$};
# \node[fill=white] at (4.9,3.6) {$A$};
# \node at (4.6,2.7) {$A \cap C_1$};
# \node at (6.5,2.7) {$A \cap C_2$};
# \node at (8.5,2.7) {$A \cap C_3$};
# \node at (10.5,2.7) {$A \cap C_4$};
# \node at (13,2.7) {$A \cap C_5$};
#
# \begin{scope}
# \clip (p11) -- (p12) -- (3,5) -- (3,1) -- cycle;
# \fill[blue, opacity=0.1] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \end{scope}
#
# \begin{scope}
# \clip (p21) -- (p22) -- (p12) -- (p11) -- cycle;
# \fill[red, opacity=0.1] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \end{scope}
#
# \begin{scope}
# \clip (p21) -- (p22) -- (p32) -- (p31) -- cycle;
# \fill[blue, opacity=0.1] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \end{scope}
#
# \begin{scope}
# \clip (p41) -- (p42) -- (p32) -- (p31) -- cycle;
# \fill[red, opacity=0.1] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \end{scope}
#
# \begin{scope}
# \clip (p41) -- (p42) -- (15,5) -- (15,1) -- cycle;
# \fill[blue, opacity=0.1] (9,2.7) ellipse[x radius=5.5cm, y radius=1.3cm];
# \end{scope}
