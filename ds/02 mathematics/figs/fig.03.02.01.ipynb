# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex -l arrows.meta,calc,positioning -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (-4,-2);
# \coordinate (righttop) at (6,4);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily}
# }
#
# \def\x{3}
# \def\y{4}
# \def\z{3}
#
# \coordinate (origin) at (0,0,0);
# \draw (origin) -- (3.6,0,0) coordinate (x-axis);
# \draw (origin) -- (0,3.3,0) coordinate (y-axis);
# \draw (origin) -- (0,0,4.5) coordinate (z-axis);
# \draw[red, ->, line width=1.5pt] (origin) -- (\x,\y,\z) coordinate (p) node[above right] {$x$};
# \draw[blue, ->, line width=1.5pt] (origin) -- (\x,0,0) coordinate (p1) node[above] {$v_1$};
# \draw[blue, ->, line width=1.5pt] (origin) -- (0,0,\z) coordinate (p2) node[above left] {$v_2$};
# \draw[gray, ->, line width=1.5pt] (origin) -- (\x,0,\z) coordinate (p12) node[pos=0.3,below] {$x^{\Vert v}$};
# \draw[gray, ->, line width=1.5pt] (p12) -- (p) node[pos=0.7,right] {$x^{\perp v}$};
# \draw[dashed] (p1) -- (p12);
# \draw[dashed] (p2) -- (p12);
# \draw (p12) ($(p12)!0.1!(origin)$) -- ++(0,0.25,0) -- ($(p12)+(0,0.25,0)$);
# \draw (p1) ($(p1)+(0,0,0.5)$) -- ++(-0.25,0,0) -- ($(p1)+(-0.25,0,0)$);
# \draw (p2) ($(p2)+(0.25,0,0)$) -- ++(0,0,-0.5) -- ($(p2)+(0,0,-0.5)$);
# \fill[red] (p) circle (2pt);
