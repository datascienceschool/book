# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,10);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \draw[->, line width=1pt] (2.5,1) -- (14.5, 1) coordinate (x) ;
# \node[right] at (x) {$x_1$};
# \draw[->, line width=1pt] (3,0.5) -- (3, 8) coordinate (y) ;
# \node[above] at (y) {$y$};
#
# \draw[line width=2pt] (2,2) -- (10, 5) coordinate (p) -- ($(2,2)!1.5!(p)$);
# \draw[dashed] (p) |- (x);
# \draw[dashed] (p) -| (y);
# \node[below] at (p |- x) {$x_1$};
# \node[left] at (p -| y) {$w_0 + w_1x_1$};
# \fill[gray] ($(p)+(0,1)$) coordinate (p2) circle (4pt);
# \draw[->, line width=2pt, dotted] (p) -- node[auto] {$\epsilon$} (p2);
# \draw[dashed] (p2) -| (y);
# \node[left] at (p2 -| y) {$w_0 + w_1x_1 + \epsilon$};
#
# \begin{scope}[shift={(10,7)}, rotate=-90]
# \begin{axis}[hide axis, xmin=-2, xmax=2, ymin=0, ymax=1, width=4cm, height=4cm, scale only axis=true]
# \addplot[line width=2pt, color=gray, domain=-2:2, samples=100] {
#     exp(-x*x)
# };
# \end{axis}
# \end{scope}
#
# \begin{scope}[shift={(10,9)}, scale=2, transform shape]
# \node {$y = w_0 + w_1 x_1 + \overbrace{w_2 x_2 + w_3 x_3 +\cdots}^{\epsilon}$};
# \end{scope}
