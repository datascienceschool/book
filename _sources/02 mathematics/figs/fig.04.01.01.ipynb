# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (10,4);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily}
# }
#
# \begin{scope}[shift={(1,1)}]
# \draw[line width=1pt] (4,2) coordinate (x0) +(0,0.1) -- +(0,-0.1) node[above=0.2] {$0$};
# \draw[line width=1pt] (5,2) coordinate (x1) +(0,0.1) -- +(0,-0.1) node[above=0.2] {$1$};
# \draw[line width=1pt] (4,0) coordinate (log0) +(0,0.1) -- +(0,-0.1) node[below=0] {$0$};
# \path (0,0) coordinate (logminf) node[below=0.1] {$-\infty$};
# \path (8,0) coordinate (logpinf) node[below=0.1] {$\infty$};
# \path (8,2) coordinate (xpinf) node[above=0.1] {$\infty$};
# \fill[blue!20] (x0) -- (x1) -- (log0) -- (logminf) -- cycle;
# \fill[blue!10] (x1) -- (log0) -- ++(4,0) -- ++(0,2) -- cycle;
# \draw[-Stealth,line width=1pt, densely dashed] (x1) -- (log0);
# \draw[-Stealth,line width=1pt, densely dashed] (x0) -- (logminf);
# \draw[->] (-0.5,2) -- (8.5,2);
# \draw[->] (-0.5,0) -- (8.5,0);
# \node at (2,2.3) {\large $x$};
# \node at (2,-0.3) {\large $\log x$};
# \end{scope}
