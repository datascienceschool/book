# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (10,5);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\scriptsize}
# }
#
# \begin{scope}[shift={(0.75,3.5)},scale=0.35,line width=0.5pt]
# \draw[rounded corners=2pt]
# (0,0) -- ++(1,-1) -- ++(-2,0) -- ++(0,-3) -- ++(8,0) -- ++(-1,-1)
# ++(3,0) -- ++(-1,1) -- ++(2,0) -- ++(0,3) -- ++(-8,0) -- ++(1,1);
# \draw[->] (1.5,0) -- (1.5,-1.5);
# \draw[->] (7.5,-3.5) -- (7.5,-5);
# \node at (1.5,1) {모수};
# \node at ($0.5*(1.5,1)+0.5*(7.5,-6)$) {성능(손실)함수};
# \node at (7.5,-6) {성능(손실)};
# \end{scope}
#
# \begin{scope}[shift={(6,1)},scale=1,line width=0.5pt]
# \draw[->] (-0.5,0) -- (3,0);
# \draw[->] (0,-0.5) -- (0,3);
# \node at (3.5,0) {모수};
# \node at (0,3.5) {성능(손실)};
# \draw[dashed] (-0.5,2) parabola[parabola height=-50] +(3,0);
# \node at (1.8,2.9) {성능함수};
# \draw (-0.5,1) parabola[parabola height=50] +(3,0);
# \node at (2.3,0.5) {손실함수};
# \draw[->] (1,-0.5) -- (1,0);
# \fill (1,0) circle (2pt);
# \node at (1,-0.7) {최적의 모수};
# \end{scope}
