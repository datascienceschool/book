# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,datavisualization,datavisualization.formats.functions -g fillbetween -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,7);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize},
#     rv/.style={draw, minimum size=1cm},
#     data/.style={draw, minimum size=2cm, shape aspect=2, cloud}
# }
#
# \begin{scope}[shift={(2,0)}]
# \node[rv, label=확률변수] (X) at (3,5) {$X$};
# \node[data, label=below:표본 데이터] (x) at (3,2) {$x$};
# \draw[->] (X) -- (x);
# \node[draw, minimum width=3cm, minimum height=1cm, label=below:데이터의 변환] (f) at (7,2) {$y=f(x)$};
# \draw[->] (x) -- (f);
# \node[data, label=below:변환된 표본 데이터] (y) at (11,2) {$y=f(x)$};
# \draw[->] (f) -- (y);
# \node[rv, label=변환된 확률변수] (Y) at (11,5) {$Y$};
# \draw[->] (Y) -- (y);
# \node[rv, minimum width=3cm, minimum height=1cm, label=확률변수의 변환] (F) at (7,5) {$Y=f(X)$};
# \draw[->] (X) -- (F);
# \draw[->] (F) -- (Y);
# \end{scope}
