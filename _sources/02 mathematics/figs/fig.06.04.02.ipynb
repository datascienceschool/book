# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes -g fillbetween -s 2000,1200 -f png
#
# \pgfplotsset{compat=1.15}
# \coordinate (leftbottom) at (0,0.5);
# \coordinate (righttop) at (20,10.5);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \pgfplotsset{width=20cm, height=9cm}
# \begin{scope}[shift={(0,2)}]
# \begin{axis}[hide axis, ymin=0, ymax=1]
# \addplot[name path=sigmoid, line width=1pt, domain=-9:9, samples=100] {
#     1 / (1 + exp( -0.5 * (x + 3)))
# };
# \addplot[name path=line, line width=1.7pt, no markers, domain=-9:9] {0};
#
# \draw[dashed] (-4,0) -- (-4,0.38) coordinate (x12) -- (-3, 0.38) coordinate (x13) ;
# \fill (-4,0.38) circle (2pt);
# \draw[dashed] (-3,0) -- (-3,0.5);
# \fill (-3,0.5) coordinate (x11) circle (2pt);
# \filldraw[fill=gray] (x11) -- (x12) -- (x13) -- cycle;
#
# \draw[dashed] (2,0) -- (2,0.92) coordinate (x22) -- (3, 0.92) coordinate (x23);
# \fill (2,0.92) circle (2pt);
# \draw[dashed] (3,0) -- (3,0.95);
# \fill (3,0.95) coordinate (x21) circle (2pt);
# \filldraw[fill=gray] (x21) -- (x22) -- (x23) -- cycle;
#
# \end{axis}
# \end{scope}
#
# \node[anchor=base] at (5.8, 1.5) {$x_1$};
# \node[anchor=base] at (6.9, 1.5) {$x_1 + dx$};
# \node[anchor=base] at (5.5, 5.1) {$F(x_1)$};
# \node[anchor=base] at (5.9, 6.0) {$F(x_1 + dx)$};
# \node[anchor=west, text width=5.5cm, align=left] (x13) at (6.6, 5.3) {$P(x_1, x_1 + dx) = F(x_1 + dx) - F(x_1)$};
#
# \node[anchor=base] at (11, 1.5) {$x_2$};
# \node[anchor=base] at (11.9, 1.5) {$x_2 + dx$};
# \node[anchor=base] at (10.5, 9.0) {$F(x_2)$};
# \node[anchor=base] at (11.9, 9.4) {$F(x_2 + dx)$};
# \node[anchor=west, text width=5.5cm, align=left] at (12.0, 8.9) {$P(x_2, x_2 + dx) = F(x_2 + dx) - F(x_2)$};
