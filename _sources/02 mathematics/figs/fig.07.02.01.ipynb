# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -e utf-8 -l arrows.meta,calc,positioning,shapes,datavisualization,datavisualization.formats.functions -g fillbetween -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,8);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \begin{scope}[shift={(5,2)}, scale=2, transform shape]
# \node {$ E[X] = \int_{-\infty}^{\infty} x \!\! \overbrace{p(x)}^{\hbox{\tiny 확률밀도함수}} \!\! dx$};
# \end{scope}
#
# \begin{scope}[shift={(5,5.5)}, scale=2, transform shape]
# \node {$\displaystyle E[X] = \sum_{x_i\in\Omega} x_i \!\! \overbrace{p(x_i)}^{\hbox{\tiny 확률질량함수}}$};
# \end{scope}
#
# \begin{scope}[shift={(11,1)}]
# \begin{axis}[hide axis, xmin=-2, xmax=4, ymin=0, ymax=1.1, width=6cm, height=3cm, scale only axis=true]
# \addplot[name path=graph1, line width=1pt, domain=-2:4, samples=100] {
#     3 / ((1 + exp(x)) * (1 + exp(-x))
# };
# \addplot[name path=graph1, line width=0.5pt, domain=0.85:1.15, samples=100, fill=lightgray] {
#     3 / ((1 + exp(x)) * (1 + exp(-x))
# } \closedcycle;
# \coordinate (x1) at (axis cs: 0.85,0.2);
# \coordinate (x2) at (axis cs: 1.15,0.2);
# \coordinate (x) at (axis cs: 1,0);
# \coordinate (fx) at (axis cs: 1, 0.7);
# \end{axis}
# \node[below] at (x) {$x$};
# \node[above] at (fx) {$p(x)$};
# \draw[<-] (x1) -- +(-0.5,0);
# \draw[<-] (x2) -- +(+0.5,0);
# \node[left] at ($(x1)+(-0.5,0.05)$) {$dx$};
# \end{scope}
#
# \begin{scope}[shift={(11,5)}]
# \begin{axis}[hide axis, xmin=-2, xmax=4, ymin=0, ymax=1.1, width=6cm, height=3cm, scale only axis=true]
# \addplot[name path=graph2, ybar, samples at={-2, -1, 0, 1, 2, 3, 4}, fill=lightgray!20] {
#     3 / ((1 + exp(x)) * (1 + exp(-x))
# };
# \addplot[name path=graph2, ybar, samples at={1}, fill=lightgray] {
#     3 / ((1 + exp(x)) * (1 + exp(-x))
# };
# \coordinate (x) at (axis cs: 1,0);
# \coordinate (Px) at (axis cs: 1, 0.6);
# \end{axis}
# \node[below] at (x) {$x_i$};
# \node[above] at (Px) {$p(x_i)$};
# \end{scope}
