# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,shapes.arrows -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,6);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \tikzset{
# sample/.style={font={\ttfamily\Large}, shape=circle, draw},
# event/.style={draw, densely dotted, shape=rectangle, rounded corners=2pt},
# every pin/.style={draw, pin edge={thick}}
# }
#
# \draw[rounded corners, line width=2pt] (1,1) rectangle (7,5);
# \node[fill=white, font={\ttfamily\large}] at (4,5) {표본공간 $\Omega$};
# \node[sample] at (3,3) {H};
# \node[sample] at (5,3) {T};
#
# \draw[rounded corners, line width=1pt, loosely dashed] (9,1) rectangle (19,5);
# \node[fill=white, font={\ttfamily\large}] at (14,5) {사건(부분집합)의 집합};
# \node[shape=single arrow, draw, minimum height=1cm] at (8,3) {};
# \node[event, label={A}, pin={5:$0$}] at (10,3.5) {$\{\}$};
# \node[event, label={B}, pin={5:$0.4$}] at (10,2) {$\{H\}$};
# \node[event, label={C}, pin={5:$0.6$}] at (15,3.5) {$\{T\}$};
# \node[event, label={D}, pin={5:$1$}] at (15,2) {$\{H,T\}$};
