# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes,shapes.arrows -g fillbetween -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,7);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \draw[rounded corners, line width=2pt] (1,1) rectangle (8,6.5);
# \node[draw, circle, minimum height=4cm, line width=2pt, fill=lightgray] at (3.5,3.5) {};
# \node[draw, circle, minimum height=4cm] at (5.5,3.5) {};
# \node[fill=white, font={\ttfamily\Large}] at (4.5,6.5) {$\Omega$};
# \node[fill=white, font={\ttfamily\Large}] at (3.5,5.9) {$A$};
# \node[fill=white, font={\ttfamily\Large}] at (5.5,5.9) {$B$};
#
# \node[draw, single arrow, minimum height=2.4cm, minimum width=2cm] at (9.9,4) {};
#
# \draw[rounded corners, dashed] (12,1) rectangle (19,6.5);
# \begin{scope}
# \clip (16.5,3.5) circle (2);
# \node[draw, circle, minimum height=4cm, fill=lightgray] at (14.5,3.5) {};
# \end{scope}
# \node[draw, circle, minimum height=4cm] at (14.5,3.5) {};
# \node[draw, circle, minimum height=4cm, line width=2pt] at (16.5,3.5) {};
# \node[fill=white, font={\ttfamily\Large}] at (16.9,5.9) {$B=\Omega_{new}$};
# \node[fill=lightgray, font={\ttfamily\Large}] at (15.5,4.2) {$A_{new}$};
# \node[fill=lightgray, font={\ttfamily\Large}] at (15.5,3.6) {$=$};
# \node[fill=lightgray, font={\ttfamily\Large}] at (15.5,3.2) {$A\cap B$};
