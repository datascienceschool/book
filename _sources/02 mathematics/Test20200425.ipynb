# %%
from PIL import Image

# %%
img = Image.open("gan.png").convert('L')

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=587x578 at 0x7F7318066D68>

# %%
A = np.array(img)

# %%
A.shape[0] * A.shape[1]
# Out:
# 339286

# %%
B = np.array(img.crop((0, 0, 578, 578)))

# %%
B = B + B.T

# %%
plt.imshow(B)
plt.grid(False)
plt.show()

# %%
w, V = np.linalg.eig(B)

# %%
plt.imshow(np.real(w[0] * V[:, :1] @ V[:, :1].T + 
                   w[1] * V[:, 1:2] @ V[:, 1:2].T + 
                   w[2] * V[:, 2:3] @ V[:, 2:3].T + 
                   w[3] * V[:, 3:4] @ V[:, 3:4].T + 
                   w[4] * V[:, 4:5] @ V[:, 4:5].T + 
                   w[5] * V[:, 5:6] @ V[:, 5:6].T + 
                   w[6] * V[:, 6:7] @ V[:, 6:7].T + 
                   w[7] * V[:, 7:8] @ V[:, 7:8].T +
                   w[8] * V[:, 8:9] @ V[:, 8:9].T + 
                   w[9] * V[:, 9:10] @ V[:, 9:10].T + 
                   w[10] * V[:, 10:11] @ V[:, 10:11].T + 
                   w[11] * V[:, 11:12] @ V[:, 11:12].T + 
                   w[12] * V[:, 12:13] @ V[:, 12:13].T + 
                   w[13] * V[:, 13:14] @ V[:, 13:14].T + 
                   w[14] * V[:, 14:15] @ V[:, 14:15].T
                  ))
plt.show()

# %%
U, S, VT = np.linalg.svd(A)

# %%
plt.imshow(np.real(S[0] * U[:, :1] @ VT[:1, :]  
                 + S[1] * U[:, 1:2] @ VT[1:2, :]  
                 + S[2] * U[:, 2:3] @ VT[2:3, :]  
                 + S[3] * U[:, 3:4] @ VT[3:4, :]  
                 + S[4] * U[:, 4:5] @ VT[4:5, :]  
                 + S[5] * U[:, 5:6] @ VT[5:6, :]  
                 + S[6] * U[:, 6:7] @ VT[6:7, :]  
                  ))
plt.show()

# %%
7 * (1 + 578 + 587) / (578 * 587)
# Out:
# 0.024056400794609856
