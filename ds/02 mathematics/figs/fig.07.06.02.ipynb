# %%
# %load_ext tikzmagic

# %%
# %%tikz -p kotex,pgfplots -l arrows.meta,calc,positioning,shapes -s 2000,1200 -f png
#
# \coordinate (leftbottom) at (0,0);
# \coordinate (righttop) at (20,10);
# \fill[white,use as bounding box] (leftbottom) rectangle (righttop);
# \draw[help lines,white] (leftbottom) grid (righttop);
# \tikzset{
#     >=stealth,font={\ttfamily\normalsize}
# }
#
# \draw[->, line width=1pt] (2.5,1) -- (17.5, 1) coordinate (x) ;
# \node[right] at (x) {$x$};
# \draw[->, line width=1pt] (3,0.5) -- (3, 8) coordinate (y) ;
# \node[above] at (y) {$y$};
#
# \path (2,2) -- (5,3) coordinate (p1) -- (11,5) coordinate (p2)  -- (17,7);
#
# \draw[dashed] (5,1) -- (5, 8);
# \node[below] at (p1 |- x) {$x_1$};
#
# \begin{scope}[shift={(5,5)}, rotate=-90]
# \begin{axis}[hide axis, xmin=-2, xmax=2, ymin=-0.01, ymax=1.01, width=4cm, height=4cm, scale only axis=true]
# \addplot[line width=2pt, color=gray, domain=-2:2, samples=100] {
#     exp(-4*x*x)
# };
# \end{axis}
# \end{scope}
# \node at (9,2.5) {$p_{Y|X}(y|x_1)$};
#
# \draw[->, line width=1pt] (6, 4) -- (6, 3.6);
# \draw[->, line width=1pt] (6, 2) -- (6, 2.4);
# \node at (6.5, 4.3) {${\rm Var}_Y[Y \vert X=x_1] $};
#
# \draw[dashed] (11,1) -- (11, 8);
# \node[below] at (p2 |- x) {$x_2$};
#
# \begin{scope}[shift={(11,7)}, rotate=-90]
# \begin{axis}[hide axis, xmin=-2, xmax=2, ymin=-0.01, ymax=1.01, width=4cm, height=4cm, scale only axis=true]
# \addplot[line width=2pt, color=gray, domain=-2:2, samples=100] {
#     exp(-4*x*x)
# };
# \end{axis}
# \end{scope}
# \node at (15,4.5) {$p_{Y|X}(y|x_2)$};
#
# \draw[->, line width=1pt] (12, 6) -- (12, 5.6);
# \draw[->, line width=1pt] (12, 4) -- (12, 4.4);
# \node at (12.5, 6.3) {${\rm Var}_Y[Y \vert X=x_2] $};
